# %% [markdown]
# <a href="https://colab.research.google.com/github/iamnovocaine/inf_search/blob/main/6_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d4cf0571-658a-4a05-bfe0-8b342ed0bc96" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d4cf0571-658a-4a05-bfe0-8b342ed0bc96">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Тексты9.zip to Тексты9.zip

# %%
import zipfile
with zipfile.ZipFile("Тексты9.zip","r") as zip_ref:
    zip_ref.extractall("Тексты9")

# !wget http://download.cdn.yandex.net/mystem/mystem-3.0-linux3.1-64bit.tar.gz
# !tar -xvf mystem-3.0-linux3.1-64bit.tar.gz
# !cp mystem /root/.local/bin/mystem

from pymystem3 import Mystem
mystem = Mystem(disambiguation=True)

import numpy as np
import matplotlib.pyplot as plt
import math
# Out:
# --2021-01-19 06:52:11--  http://download.cdn.yandex.net/mystem/mystem-3.0-linux3.1-64bit.tar.gz
# Resolving download.cdn.yandex.net (download.cdn.yandex.net)... 5.45.205.242, 5.45.205.245, 5.45.205.244, ...
# Connecting to download.cdn.yandex.net (download.cdn.yandex.net)|5.45.205.242|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: http://cache-mskm909.cdn.yandex.net/download.cdn.yandex.net/mystem/mystem-3.0-linux3.1-64bit.tar.gz [following]
# --2021-01-19 06:52:12--  http://cache-mskm909.cdn.yandex.net/download.cdn.yandex.net/mystem/mystem-3.0-linux3.1-64bit.tar.gz
# Resolving cache-mskm909.cdn.yandex.net (cache-mskm909.cdn.yandex.net)... 5.45.220.19, 2a02:6b8:0:2002::1a
# Connecting to cache-mskm909.cdn.yandex.net (cache-mskm909.cdn.yandex.net)|5.45.220.19|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16457938 (16M) [application/octet-stream]
# Saving to: ‘mystem-3.0-linux3.1-64bit.tar.gz.1’
#
# mystem-3.0-linux3.1 100%[===================>]  15.70M  4.85MB/s    in 4.0s
#
# 2021-01-19 06:52:17 (3.94 MB/s) - ‘mystem-3.0-linux3.1-64bit.tar.gz.1’ saved [16457938/16457938]
#
# mystem

# %%
import re
from prettytable import PrettyTable 
import os
import copy
import pandas as pd

terms = {} #словарь слово - количество раз в текстах
rangs = {} #словарь количество раз - ранг
stops = []
documents = {}
filenames = []
vector = list()
termsSorted = {}

requests = [
  ["полив", "яблоня"],
  ["содержание", "вода", "почва"],
  ["потребность", "культура", "влага"],
  ["земля", "вода"],
  ["способ","посадка", "плодовый", "дерево"]
]

metrics = [
    ["17.txt", "18.txt"],
    ["12.txt", "14.txt", "17.txt", "N02.txt", "N03.txt", "N04.txt", "N05.txt", "N06.txt", "N14.txt"],
    ["15.txt", "16.txt", "N06.txt"],
    ["12.txt", "N01.txt", "N02.txt", "N03.txt", "N04.txt", "N05.txt", "N07.txt", "N10.txt", "N12.txt"],
    ["18.txt"]
]
Words = []
for onerequest in requests:
  for one_term_in_request in onerequest:
    Words.append(one_term_in_request)

# составляем индекс поисковой системы
for root, dirs, files in os.walk("Тексты9"):  
  for filename in files:
      terms_in_one = {} #словарь слово - количество раз в одном тексте
      raw = []
      # print("открываем  файл " + filename)
      raw = open("Тексты9/" + filename , 'r', encoding='utf8').read()
      
      # записываем в словарь 'terms' термы из документов
      for txt in mystem.lemmatize(raw):
          if str(txt).isalpha():
            res = mystem.analyze(str(txt))
            if res[0]['analysis'] and len(str(txt)) > 1:
              if res[0]['analysis'][0]['gr'].startswith("S,") or res[0]['analysis'][0]['gr'].startswith("A=") or res[0]['analysis'][0]['gr'].startswith("V") or res[0]['analysis'][0]['gr'].startswith("A,"):
                if str(txt) in terms:
                  terms[str(txt)] = terms[str(txt)] + 1
                else:
                  terms[str(txt)] = 1

                if str(txt) in terms_in_one:
                  terms_in_one[str(txt)] = terms_in_one[str(txt)] + 1
                else:
                  terms_in_one[str(txt)] = 1
              else:
                stops.append(str(txt))
      documents[str(filename)] = terms_in_one
      filenames.append(filename)

for word in sorted(terms, key=terms.get, reverse=True)[:500]:
  termsSorted[str(word)] = terms[word]

i = 0
for filename in filenames:    
  vector.append(list())  
  for word in termsSorted:
    if word in documents[filename]:
      vector[i].append(documents[filename][word])
    else:
      vector[i].append(0)
  i += 1

matrix = pd.DataFrame(data=vector, columns=termsSorted.keys())
matrix.index = filenames

matrix['max_tf'] = matrix.max(axis=1).astype(int)
matrix
# Out:
#          почва  вода  растение  ...  папоротник  кислый  max_tf
# N15.txt     11    26        11  ...           1       1      33
# 11.txt       5    23        30  ...           1       0      30
# 17.txt      20    21        22  ...           0       0      23
# 16.txt      13    18        15  ...           0       0      18
# 19.txt      11     3         0  ...           0       0      11
# N20.txt      0    25        29  ...           2       0      29
# N04.txt     48    71        15  ...           0       0      71
# N05.txt     67    45         7  ...           0       0      67
# N08.txt     54    16        24  ...           0       0      54
# 14.txt      30     5         2  ...           0       0      30
# N11.txt     16     8         4  ...           0       0      16
# 13.txt      37    32         7  ...           0       0      37
# 18.txt      15    13         6  ...           0       0      29
# 12.txt      45    27         6  ...           0       0      45
# N17.txt      0     7         3  ...           0       0      13
# N12.txt     52    29        24  ...           0       0      52
# N16.txt     14    14         4  ...           0       0      14
# N03.txt     40    27        18  ...           0       0      40
# N13.txt      6    15        20  ...           1       0      20
# N14.txt     51    53        23  ...           0       0      53
# N18.txt      8     8        31  ...           0       2      31
# N01.txt     10    17         0  ...           0       0      17
# N10.txt      4     4        20  ...           1       3      25
# N02.txt     13    26         9  ...           0       0      26
# N09.txt      1     7        25  ...           1       0      28
# N06.txt     23    10        11  ...           0       0      23
# N07.txt     29    55        26  ...           0       1      55
# N19.txt      4     1         5  ...           0       0       7
# 15.txt       6     7        18  ...           0       0      18
#
# [29 rows x 501 columns]

# %%
import math
import copy

Num = len(list(matrix.index))
idfs = {}
for col in matrix.columns:
  idfs[col] = math.log(Num / sum(matrix.apply(lambda item: 1 if item[col] != 0 else 0, axis=1)))
  
matrix_vector_tf_max = copy.deepcopy(matrix)
matrix_vector_tf_max = matrix_vector_tf_max.apply(lambda item: item / item.max_tf, axis=1)
matrix_vector_tf_max = matrix_vector_tf_max.append(pd.Series(idfs.values(), index=idfs.keys(), name="IDFs"))
matrix_vector_tf_max
# Out:
#             почва      вода  растение  ...  папоротник    кислый  max_tf
# N15.txt  0.333333  0.787879  0.333333  ...    0.030303  0.030303     1.0
# 11.txt   0.166667  0.766667  1.000000  ...    0.033333  0.000000     1.0
# 17.txt   0.869565  0.913043  0.956522  ...    0.000000  0.000000     1.0
# 16.txt   0.722222  1.000000  0.833333  ...    0.000000  0.000000     1.0
# 19.txt   1.000000  0.272727  0.000000  ...    0.000000  0.000000     1.0
# N20.txt  0.000000  0.862069  1.000000  ...    0.068966  0.000000     1.0
# N04.txt  0.676056  1.000000  0.211268  ...    0.000000  0.000000     1.0
# N05.txt  1.000000  0.671642  0.104478  ...    0.000000  0.000000     1.0
# N08.txt  1.000000  0.296296  0.444444  ...    0.000000  0.000000     1.0
# 14.txt   1.000000  0.166667  0.066667  ...    0.000000  0.000000     1.0
# N11.txt  1.000000  0.500000  0.250000  ...    0.000000  0.000000     1.0
# 13.txt   1.000000  0.864865  0.189189  ...    0.000000  0.000000     1.0
# 18.txt   0.517241  0.448276  0.206897  ...    0.000000  0.000000     1.0
# 12.txt   1.000000  0.600000  0.133333  ...    0.000000  0.000000     1.0
# N17.txt  0.000000  0.538462  0.230769  ...    0.000000  0.000000     1.0
# N12.txt  1.000000  0.557692  0.461538  ...    0.000000  0.000000     1.0
# N16.txt  1.000000  1.000000  0.285714  ...    0.000000  0.000000     1.0
# N03.txt  1.000000  0.675000  0.450000  ...    0.000000  0.000000     1.0
# N13.txt  0.300000  0.750000  1.000000  ...    0.050000  0.000000     1.0
# N14.txt  0.962264  1.000000  0.433962  ...    0.000000  0.000000     1.0
# N18.txt  0.258065  0.258065  1.000000  ...    0.000000  0.064516     1.0
# N01.txt  0.588235  1.000000  0.000000  ...    0.000000  0.000000     1.0
# N10.txt  0.160000  0.160000  0.800000  ...    0.040000  0.120000     1.0
# N02.txt  0.500000  1.000000  0.346154  ...    0.000000  0.000000     1.0
# N09.txt  0.035714  0.250000  0.892857  ...    0.035714  0.000000     1.0
# N06.txt  1.000000  0.434783  0.478261  ...    0.000000  0.000000     1.0
# N07.txt  0.527273  1.000000  0.472727  ...    0.000000  0.018182     1.0
# N19.txt  0.571429  0.142857  0.714286  ...    0.000000  0.000000     1.0
# 15.txt   0.333333  0.388889  1.000000  ...    0.000000  0.000000     1.0
# IDFs     0.071459  0.000000  0.071459  ...    1.575536  1.981001     0.0
#
# [30 rows x 501 columns]

# %%
matrix_vector_wtj = copy.deepcopy(matrix_vector_tf_max)
for col in matrix_vector_wtj:
  matrix_vector_wtj[col] *= matrix_vector_wtj[col].IDFs
matrix_vector_wtj = matrix_vector_wtj.drop(columns='max_tf')[0:29]
matrix_vector_wtj
# Out:
#             почва  вода  растение  ...  благоприятный  папоротник    кислый
# N15.txt  0.023820   0.0  0.023820  ...       0.047744    0.047744  0.060030
# 11.txt   0.011910   0.0  0.071459  ...       0.000000    0.052518  0.000000
# 17.txt   0.062138   0.0  0.068352  ...       0.000000    0.000000  0.000000
# 16.txt   0.051609   0.0  0.059549  ...       0.000000    0.000000  0.000000
# 19.txt   0.071459   0.0  0.000000  ...       0.000000    0.000000  0.000000
# N20.txt  0.000000   0.0  0.071459  ...       0.000000    0.108658  0.000000
# N04.txt  0.048310   0.0  0.015097  ...       0.000000    0.000000  0.000000
# N05.txt  0.071459   0.0  0.007466  ...       0.000000    0.000000  0.000000
# N08.txt  0.071459   0.0  0.031760  ...       0.029177    0.000000  0.000000
# 14.txt   0.071459   0.0  0.004764  ...       0.000000    0.000000  0.000000
# N11.txt  0.071459   0.0  0.017865  ...       0.000000    0.000000  0.000000
# 13.txt   0.071459   0.0  0.013519  ...       0.000000    0.000000  0.000000
# 18.txt   0.036962   0.0  0.014785  ...       0.000000    0.000000  0.000000
# 12.txt   0.071459   0.0  0.009528  ...       0.000000    0.000000  0.000000
# N17.txt  0.000000   0.0  0.016491  ...       0.000000    0.000000  0.000000
# N12.txt  0.071459   0.0  0.032981  ...       0.000000    0.000000  0.000000
# N16.txt  0.071459   0.0  0.020417  ...       0.000000    0.000000  0.000000
# N03.txt  0.071459   0.0  0.032157  ...       0.078777    0.000000  0.000000
# N13.txt  0.021438   0.0  0.071459  ...       0.000000    0.078777  0.000000
# N14.txt  0.068762   0.0  0.031010  ...       0.029727    0.000000  0.000000
# N18.txt  0.018441   0.0  0.071459  ...       0.000000    0.000000  0.127807
# N01.txt  0.042035   0.0  0.000000  ...       0.000000    0.000000  0.000000
# N10.txt  0.011433   0.0  0.057167  ...       0.000000    0.063021  0.237720
# N02.txt  0.035729   0.0  0.024736  ...       0.000000    0.000000  0.000000
# N09.txt  0.002552   0.0  0.063803  ...       0.000000    0.056269  0.000000
# N06.txt  0.071459   0.0  0.034176  ...       0.068502    0.000000  0.000000
# N07.txt  0.037678   0.0  0.033781  ...       0.028646    0.000000  0.036018
# N19.txt  0.040834   0.0  0.051042  ...       0.000000    0.000000  0.000000
# 15.txt   0.023820   0.0  0.071459  ...       0.000000    0.000000  0.000000
#
# [29 rows x 500 columns]

# %%
index = 0

alpha = 1
beta = 0.75
gamma = 0.15 


# import warnings
for onerequest in requests:
  print("Запрос: ")
  print(' '.join(onerequest))

  #  запускаем первый раз
  output = {}
  tftq = {}
  idftq = {}
  wtq = {}

  a = 0
  b = 0
  c = 0
  d = 0
  list_of_found_relevant_docs = []
  list_of_found_nonrelevant_docs = []

  # идем по словам в запросе
  for one_term_in_request in onerequest:
    tftq[one_term_in_request] = onerequest.count(one_term_in_request)
    if one_term_in_request in idfs: 
      idftq[one_term_in_request] = idfs[one_term_in_request]
    else: 
      idftq[one_term_in_request] = 0
  for one_term_in_request in onerequest:
    wtq[one_term_in_request] = (0.5 + (0.5 * tftq[one_term_in_request]) / max(tftq.values())) * idftq[one_term_in_request]
    if one_term_in_request not in matrix_vector_wtj:
      matrix_vector_wtj[one_term_in_request] = 0
  # print(wtq)
  i = 0

  while i < Num:  
    sim = np.dot(list(matrix_vector_wtj[onerequest].iloc[i]), list(wtq.values())) / (np.linalg.norm(list(matrix_vector_wtj[onerequest].iloc[i])) \
      * np.linalg.norm(list(wtq.values())))
    
    if math.isnan(sim):
      sim = 0
    if sim > 0.84: # можем менять отсечку релевантности
      output[matrix_vector_wtj.index[i]] = sim
    i += 1
    output_sorted = {k: v for k, v in sorted(output.items(), key=lambda item: -item[1])}

    i += 1

  for doc in output_sorted.keys():
    print(doc, output_sorted[doc])
    if doc in metrics[index]:
      a = a + 1
      list_of_found_relevant_docs.append(doc)
    else:
      b = b + 1
      list_of_found_nonrelevant_docs.append(doc)
  c = len(metrics[index]) - a
  d = len(filenames) - len(metrics[index]) - b

  print("d = " + str(d) + ", a = " + str(a) + ", b = " + str(b) + ", c = " + str(c))
  print(list_of_found_relevant_docs)
  print(list_of_found_nonrelevant_docs)
  print()
  
  if (a + c) == 0:
    recall = 0
  else:
    recall = a / (a + c)

  if (a + b) == 0:
    precision = 0
  else:
    precision = a / (a + b)

  if (b + d) == 0:
    fallout = 0
  else:
    fallout = b / (b + d)

  if recall == 0 or precision == 0:
    fvalue = 0
  else:
    fvalue = 2 / (1 / precision + 1 / recall)
  print("recall= " + str(recall) + ", precision = " + str(precision) + ", fallout = " + str(fallout))
  print("accuracy= " + str(accuracy) + ", fvalue = " + str(fvalue) + "\n\n")
  
  print()
  print("После пересчета весов")
  print()


  # Это векторная модель, в которой ты после первого запроса пересчитываются весовые коэффициенты 
  # и снова запускается запрос с новыми весами. 

  for one_term_in_request in onerequest:
    relevant_docs_sum = 0
    not_relevant_docs_sum = 0

    for doc in list_of_found_relevant_docs:
      relevant_docs_sum += matrix_vector_wtj[one_term_in_request][doc]

    for doc in list_of_found_nonrelevant_docs:
      not_relevant_docs_sum += matrix_vector_wtj[one_term_in_request][doc]

    wtq[one_term_in_request] = alpha * wtq[one_term_in_request]
    if len(list_of_found_relevant_docs) > 0:
      wtq[one_term_in_request] += beta / len(list_of_found_relevant_docs) * relevant_docs_sum
    if len(list_of_found_nonrelevant_docs) > 0:
      wtq[one_term_in_request] -= gamma / len(list_of_found_nonrelevant_docs) * not_relevant_docs_sum

  # запускается второй раз
  output = {}
  a = 0
  b = 0
  c = 0
  d = 0
  i = 0
  while i < Num:  
    sim = np.dot(list(matrix_vector_wtj[onerequest].iloc[i]), list(wtq.values())) / (np.linalg.norm(list(matrix_vector_wtj[onerequest].iloc[i])) \
      * np.linalg.norm(list(wtq.values())))
    
    if math.isnan(sim):
      sim = 0
    if sim > 0.84: # можем менять отсечку релевантности
      output[matrix_vector_wtj.index[i]] = sim
    i += 1
    output_sorted = {k: v for k, v in sorted(output.items(), key=lambda item: -item[1])}

    i += 1

  for doc in output_sorted.keys():
    print(doc, output_sorted[doc])
    if doc in metrics[index]:
      a = a + 1
    else:
      b = b + 1
  c = len(metrics[index]) - a
  d = len(filenames) - len(metrics[index]) - b

  print("d = " + str(d) + ", a = " + str(a) + ", b = " + str(b) + ", c = " + str(c))
  print()

  if (a + c) == 0:
    recall = 0
  else:
    recall = a / (a + c)

  if (a + b) == 0:
    precision = 0
  else:
    precision = a / (a + b)

  if (b + d) == 0:
    fallout = 0
  else:
    fallout = b / (b + d)
  accuracy = (a + d) / (a + b + c + d)

  if recall == 0 or precision == 0:
    fvalue = 0
  else:
    fvalue = 2 / (1 / precision + 1 / recall)
  print("recall= " + str(recall) + ", precision = " + str(precision) + ", fallout = " + str(fallout))
  print("accuracy= " + str(accuracy) + ", fvalue = " + str(fvalue) + "\n\n") 
  print("----\n")
  index = index + 1
# Out:
# Запрос:
# полив яблоня
# N15.txt 1.0
# 17.txt 1.0
# N04.txt 1.0
# N08.txt 1.0
# N11.txt 1.0
# 18.txt 1.0
# N18.txt 1.0
# N07.txt 1.0
# 15.txt 1.0
# d = 20, a = 2, b = 7, c = 0
# ['17.txt', '18.txt']
# ['N15.txt', 'N04.txt', 'N08.txt', 'N11.txt', 'N18.txt', 'N07.txt', '15.txt']
#
# recall= 1.0, precision = 0.2222222222222222, fallout = 0.25925925925925924
# accuracy= 0.5517241379310345, fvalue = 0.36363636363636365
#
#
#
# После пересчета весов
#
# N15.txt 1.0
# 17.txt 1.0
# N04.txt 1.0
# N08.txt 1.0
# N11.txt 1.0
# 18.txt 1.0
# N18.txt 1.0
# N07.txt 1.0
# 15.txt 1.0
# d = 20, a = 2, b = 7, c = 0
#
# recall= 1.0, precision = 0.2222222222222222, fallout = 0.25925925925925924
# accuracy= 0.7586206896551724, fvalue = 0.36363636363636365
#
#
# ----
#
# Запрос:
# содержание вода почва
# N07.txt 0.9689574001243353
# N10.txt 0.9465436725642631
# N08.txt 0.8462610791026469
# d = 17, a = 0, b = 3, c = 9
# []
# ['N07.txt', 'N10.txt', 'N08.txt']
#
# recall= 0.0, precision = 0.0, fallout = 0.15
# accuracy= 0.7586206896551724, fvalue = 0
#
#
#
# После пересчета весов
#
# N07.txt 0.9669336670730826
# N10.txt 0.9439134799801387
# N08.txt 0.8419403161171022
# d = 17, a = 0, b = 3, c = 9
#
# recall= 0.0, precision = 0.0, fallout = 0.15
# accuracy= 0.5862068965517241, fvalue = 0
#
#
# ----
#
# Запрос:
# потребность культура влага
# 18.txt 0.9991592868105859
# N13.txt 0.9749828258692963
# N15.txt 0.9443974432767267
# N10.txt 0.9078892121350566
# d = 22, a = 0, b = 4, c = 3
# []
# ['18.txt', 'N13.txt', 'N15.txt', 'N10.txt']
#
# recall= 0.0, precision = 0.0, fallout = 0.15384615384615385
# accuracy= 0.5862068965517241, fvalue = 0
#
#
#
# После пересчета весов
#
# 18.txt 0.9991354478524376
# N13.txt 0.9747564684945852
# N15.txt 0.9445863668737168
# N10.txt 0.9075245264030871
# d = 22, a = 0, b = 4, c = 3
#
# recall= 0.0, precision = 0.0, fallout = 0.15384615384615385
# accuracy= 0.7586206896551724, fvalue = 0
#
#
# ----
#
# Запрос:
# земля вода
# N15.txt 1.0
# 19.txt 1.0
# N11.txt 1.0
# N17.txt 1.0
# N16.txt 1.0
# N13.txt 1.0
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:41: RuntimeWarning: invalid value encountered in double_scalars
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:122: RuntimeWarning: invalid value encountered in double_scalars
# N18.txt 1.0
# N10.txt 1.0
# N09.txt 1.0
# N07.txt 1.0
# 15.txt 1.0
# d = 11, a = 2, b = 9, c = 7
# ['N10.txt', 'N07.txt']
# ['N15.txt', '19.txt', 'N11.txt', 'N17.txt', 'N16.txt', 'N13.txt', 'N18.txt', 'N09.txt', '15.txt']
#
# recall= 0.2222222222222222, precision = 0.18181818181818182, fallout = 0.45
# accuracy= 0.7586206896551724, fvalue = 0.2
#
#
#
# После пересчета весов
#
# N15.txt 1.0
# 19.txt 1.0
# N11.txt 1.0
# N17.txt 1.0
# N16.txt 1.0
# N13.txt 1.0
# N18.txt 1.0
# N10.txt 1.0
# N09.txt 1.0
# N07.txt 1.0
# 15.txt 1.0
# d = 11, a = 2, b = 9, c = 7
#
# recall= 0.2222222222222222, precision = 0.18181818181818182, fallout = 0.45
# accuracy= 0.4482758620689655, fvalue = 0.2
#
#
# ----
#
# Запрос:
# способ посадка плодовый дерево
# d = 28, a = 0, b = 0, c = 1
# []
# []
#
# recall= 0.0, precision = 0, fallout = 0.0
# accuracy= 0.4482758620689655, fvalue = 0
#
#
#
# После пересчета весов
#
# d = 28, a = 0, b = 0, c = 1
#
# recall= 0.0, precision = 0, fallout = 0.0
# accuracy= 0.9655172413793104, fvalue = 0
#
#
# ----
